# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt

# %%
#CIF-117 3x3->bn->1x1 nonlinear_dropout
#CIF-111 3x3->bn->1x1 nonlinear_dropout
#CIF-109 3x3->bn->1x1 linear
#CIF-105 3x3 nonlinear_dropout
###CIF-101 3x3 linear - zla, mialo byc 103 czy co

# %%
df = pd.DataFrame({
    "a": [0.706, 0.741, 0.742, 0.742, 0.750],
    "b": [0.556, 0.619, 0.667, 0.734, 0.735],
    "c": [0.673, 0.695, 0.646, 0.737, 0.737],
    "d": [0.657, 0.634, 0.675, 0.727, 0.709],
})
df.index = [1, 2, 3, 4, "baseline"]

# %%
sns.heatmap(100 * df, annot=True, fmt=".1f")
plt.savefig("sews.pdf")

# %%
plt
